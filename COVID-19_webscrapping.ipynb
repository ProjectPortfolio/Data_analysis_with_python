# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.worldometers.info/coronavirus/")

# %%
page
# Out:
# <Response [200]>

# %%
soup =BeautifulSoup(page.content,'html.parser')

# %%
table = soup.find(id="main_table_countries_today")

# %%
corona_cases =table.find_all('tr')

# %%
data =[]
for i in corona_cases:
    x=i.text.split('\n')
    row=[]
    for j in x:
        if j=='' and j:
            continue
        row.append(j)
    data.append(row)

# %%
import pandas as pd
df=pd.DataFrame(data)
df
# Out:
#     0               1              2         3            4          5  \
# 0       Country,Other     TotalCases  NewCases  TotalDeaths  NewDeaths
# 1                      North America                508,193     +7,973
# 2                             Europe                794,634    +15,782
# 3                               Asia                268,866     +4,969
# 4                      South America                 40,191       +586
# ..  ..            ...            ...       ...          ...        ...
# 224            Total:         40,191      +586        1,630        +15
# 225            Total:          7,573       +96           55         +3
# 226            Total:         13,133      +253          655        +23
# 227            Total:            721                     13
# 228            Total:      1,633,311   +29,659       99,479     +3,787
#
#                   6            7                 8                 9  \
# 0    TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
# 1            18,836       +1,170            32,448           456,909
# 2            68,186       +2,368           190,671           535,777
# 3            10,104         +208           133,251           125,511
# 4             1,630          +15             4,129            34,432
# ..              ...          ...               ...               ...
# 224           4,129       34,432             1,128
# 225           3,515        4,003                79
# 226           2,077       10,401               154
# 227             619           89                10
# 228         366,710    1,167,122            49,416             209.5
#
#                 10          11      12                 13 14             15  \
# 0    Deaths/1M pop  TotalTests  Tests/             1M pop         Continent
# 1           11,139                                            North America
# 2           30,404                                                   Europe
# 3            6,502                                                     Asia
# 4            1,128                                            South America
# ..             ...         ...     ...                ... ..            ...
# 224                                         South America              None
# 225                                     Australia/Oceania              None
# 226                                                Africa              None
# 227                                                                    None
# 228           12.8                                    All              None
#
#        16
# 0
# 1
# 2
# 3
# 4
# ..    ...
# 224  None
# 225  None
# 226  None
# 227  None
# 228  None
#
# [229 rows x 17 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d275f3df2ae9> in <module>
# ----> 1 df.set_index(Country,Other)
#
# NameError: name 'Country' is not defined
