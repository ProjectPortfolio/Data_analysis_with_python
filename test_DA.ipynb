# %%
import pandas as pd

# %%
df = pd.read_csv('earthquake.csv')

# %%
#1)
df.head()
# Out:
#                       time   latitude  longitude  depth   mag magType  nst  \
# 0  2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml  NaN
# 1  2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml  4.0
# 2  2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml  NaN
# 3  2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml  NaN
# 4  2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml  6.0
#
#       gap     dmin     rms net          id                   updated  \
# 0     NaN      NaN  0.2900  ak  ak11155107  2014-02-05T19:34:41.515Z
# 1  171.43  0.34200  0.0247  nn  nn00436847  2014-02-01T01:35:09.000Z
# 2     NaN      NaN  1.0000  ak  ak11151142  2014-02-01T00:03:53.010Z
# 3     NaN      NaN  1.0700  ak  ak11151135  2014-01-31T23:41:25.007Z
# 4  285.00  0.04321  0.2000  ci  ci37171541  2014-02-01T00:13:20.107Z
#
#                                place        type
# 0  26km S of Redoubt Volcano, Alaska  earthquake
# ...

# %%
#2)
df = pd.read_csv('earthquake.csv',parse_dates=['time'],index_col='id')
df.head()
# Out:
#                               time   latitude  longitude  depth   mag magType  \
# id
# ak11155107 2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml
# nn00436847 2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml
# ak11151142 2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml
# ak11151135 2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml
# ci37171541 2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml
#
#             nst     gap     dmin     rms net                   updated  \
# id
# ak11155107  NaN     NaN      NaN  0.2900  ak  2014-02-05T19:34:41.515Z
# nn00436847  4.0  171.43  0.34200  0.0247  nn  2014-02-01T01:35:09.000Z
# ak11151142  NaN     NaN      NaN  1.0000  ak  2014-02-01T00:03:53.010Z
# ak11151135  NaN     NaN      NaN  1.0700  ak  2014-01-31T23:41:25.007Z
# ci37171541  6.0  285.00  0.04321  0.2000  ci  2014-02-01T00:13:20.107Z
#
#                                         place        type
# ...

# %%
#3)
df.describe()
#longest magnitude=8.20 and min =-0.97
# Out:
#             latitude      longitude          depth            mag  \
# count  120108.000000  120108.000000  120107.000000  120065.000000
# mean       38.399579     -99.961402      28.375029       1.793958
# std        21.938258      82.996858      62.215416       1.343466
# min       -73.462000    -179.998900      -9.900000      -0.970000
# 25%        34.228917    -147.742025       4.100000       0.820000
# 50%        38.805300    -120.832000       9.200000       1.400000
# 75%        53.889500    -116.068100      22.880000       2.400000
# max        86.651400     179.998000     697.360000       8.200000
#
#                 nst           gap          dmin            rms
# count  59688.000000  94935.000000  85682.000000  119716.000000
# mean      17.878284    124.048978      0.893198       0.358174
# std       14.911369     68.518595      2.903966       0.364046
# min        0.000000      9.000000      0.000000       0.000000
# ...

# %%
#4)
df = df.sort_values('mag')
df.head(20)
# Out:
#                               time  latitude   longitude  depth   mag magType  \
# id
# uw60944536 2014-12-11 17:13:30.400   43.7200 -121.315333   1.58 -0.97      md
# uw60889832 2014-10-09 21:35:19.500   43.7225 -121.315700   2.10 -0.90      Md
# uw60886762 2014-10-07 07:26:23.100   43.7227 -121.313700   2.40 -0.90      Md
# uw60891597 2014-10-13 12:57:26.000   43.7238 -121.316000   2.00 -0.90      Md
# uw60908911 2014-10-23 21:02:22.200   43.7225 -121.313000   1.80 -0.90      Md
# uw60891587 2014-10-13 09:50:54.500   43.7220 -121.313500   2.30 -0.90      Md
# uw60891577 2014-10-13 06:40:26.100   43.7235 -121.313000   2.10 -0.90      Md
# uw60891307 2014-10-12 21:10:18.900   43.7250 -121.314700   1.80 -0.90      Md
# uw60882457 2014-10-02 03:53:12.000   43.7183 -121.314000   2.10 -0.90      Md
# uw60882547 2014-10-02 05:38:45.700   43.7163 -121.316700   1.00 -0.90      Md
# uw60888161 2014-09-28 09:08:29.000   43.7207 -121.315000   1.90 -0.90      Md
# ...

# %%
#5)
df['Country'] = [city.split(",")[-1] for city in df['place']]
df.head()
# Out:
#                               time  latitude   longitude  depth   mag magType  \
# id
# uw60944536 2014-12-11 17:13:30.400   43.7200 -121.315333   1.58 -0.97      md
# uw60889832 2014-10-09 21:35:19.500   43.7225 -121.315700   2.10 -0.90      Md
# uw60886762 2014-10-07 07:26:23.100   43.7227 -121.313700   2.40 -0.90      Md
# uw60891597 2014-10-13 12:57:26.000   43.7238 -121.316000   2.00 -0.90      Md
# uw60908911 2014-10-23 21:02:22.200   43.7225 -121.313000   1.80 -0.90      Md
#
#             nst    gap      dmin   rms net                   updated  \
# id
# uw60944536  3.0  190.0  0.006311  0.00  uw  2014-12-11T19:49:58.810Z
# uw60889832  NaN  162.0  0.008983  0.03  uw  2014-10-10T18:15:27.045Z
# uw60886762  NaN  158.4  0.008983  0.03  uw  2014-10-07T21:35:17.569Z
# uw60891597  NaN  176.4  0.008983  0.05  uw  2014-10-13T16:04:47.814Z
# uw60908911  NaN  154.8  0.008983  0.05  uw  2014-10-24T18:33:39.585Z
#
#                                       place        type Country
# id
# ...

# %%
#6)
df['Country'].value_counts()[:10]
# Out:
# California     44451
# Alaska         33799
# Oregon          3195
# Nevada          2905
# Washington      2788
# Hawaii          2564
# Puerto Rico     2286
# Indonesia       2124
# Oklahoma        2040
# Montana         1991
# Name: Country, dtype: int64

# %%
#7
df.dropna()
df.sort_values('mag',ascending=False)["Country"].unique()[:10]
#strongest
# Out:
# array(['Chile', 'Alaska', 'Solomon Islands', 'Papua New Guinea',
#        'El Salvador', 'Mexico', 'Indonesia', 'Fiji',
#        'Southern East Pacific Rise', 'New Zealand'], dtype=object)

# %%
df.sort_values('mag')["Country"].unique()[:10]
#weakest
# Out:
# array(['Oregon', 'Washington', 'Montana', 'Nevada', 'California',
#        'Wyoming', 'Southern California', 'Canada', 'Utah', 'Alaska'],
#       dtype=object)
