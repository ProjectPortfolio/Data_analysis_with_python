# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('weather_data_replace.csv')
df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017       -99999          7  Sunny
# 2  01-03-2017           28     -99999   Snow
# 3  01-04-2017       -99999          7      0
# 4  01-05-2017           32     -99999   Rain
# 5  01-06-2017           31          2  Sunny
# 6  01-06-2017           34          5      0

# %%
df.replace(-9999,np.NaN) #Pandas dataframe.replace() function is used to replace a string,
#regex, list, dictionary, series, number etc. from a dataframe
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017       -99999          7  Sunny
# 2  01-03-2017           28     -99999   Snow
# 3  01-04-2017       -99999          7      0
# 4  01-05-2017           32     -99999   Rain
# 5  01-06-2017           31          2  Sunny
# 6  01-06-2017           34          5      0

# %%
df.replace({'temperature' :-9999,
           'event':0},np.NaN)
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017       -99999          7  Sunny
# 2  01-03-2017           28     -99999   Snow
# 3  01-04-2017       -99999          7      0
# 4  01-05-2017           32     -99999   Rain
# 5  01-06-2017           31          2  Sunny
# 6  01-06-2017           34          5      0
