# %%
import pandas as pd

# %%
df = pd.read_csv('COVID19_line_list_data.csv')
df
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# ...

# %%
gk = df.groupby(['country','location','case_in_country','gender'])
gk.first()
# Out:
#                                               id reporting date  Unnamed: 3  \
# country   location  case_in_country gender
# Algeria   Algeria   1.0             male    1083      2/26/2020         NaN
# Australia NSW       1.0             male     767      1/25/2020         NaN
#                     2.0             male     768      1/25/2020         NaN
#                     3.0             male     769      1/25/2020         NaN
#                     5.0             female   771      1/26/2020         NaN
# ...                                          ...            ...         ...
# Vietnam   Vinh Phuc 10.0            female   760       02/04/20         NaN
#                     11.0            female   761       02/06/20         NaN
#                     13.0            female   763       02/08/20         NaN
#                     14.0            female   764       02/09/20         NaN
#                     16.0            male     766      2/13/2020         NaN
#
# ...
