# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.monster.com/jobs/search/?q=Software-Developer&where=Indiana"

# %%
page = requests.get(URL)
#page.content

# %%
soup = BeautifulSoup(page.content, 'html.parser')

results = soup.find(id='ResultsContainer')

# %%
#results.prettify()
jobs = results.find_all('section', class_='card-content')

# %%
for job in jobs:
    job_title = job.find('h2', class_='title')
    company_name = job.find('div', class_='company')
    location = job.find('div', class_='location')
    
    if None in (job_title, company_name, location):
        continue
    
    print(job_title.text)
    print(company_name.text)
    print(location.text)
# Out:
# Software Engineer
#
#
# Openlogix Corporation
#
#
#
#
#
# Indianapolis, IN
#
#
# Lead Embedded C++ Engineer (RELO Offered)
#
#
# CyberCoders
#
#
#
#
#
# New Paris, IN
#
#
# Active Safety Software Engineer
#
#
# Company Confidential
#
#
#
#
#
# Kokomo, IN
#
#
# .Net Developer
#
#
# Net 2 Source
#
#
#
#
#
# Indianapolis, IN
#
#
# Web Engineer
#
#
# Escalade Sports
#
#
#
#
#
# Evansville, IN
#
#
# Cloud Architect
#
#
# Anchor Point Technology Resources
#
#
#
#
#
# indianapolis, IN
#
#
# Sr. Java Developer
#
#
# Beacon Hill Staffing Group, LLC
#
#
#
#
#
# Indianapolis, IN
#
#
# Computer Programmer
#
#
# Bowhead
#
#
#
#
#
# Crane, IN
#
#
# C#.net Developer with Mobile Experience
#
#
# Interactive Business Systems
#
#
#
#
#
# Indianapolis, IN
#
#
# Senior Java Developer
#
#
# Indiana Farm Bureau Insurance
#
#
#
#
#
# Indianapolis, IN
#
#
# Senior Systems Engineer
#
#
# Konane Solutions
#
#
#
#
#
# Dallas, TX
#
#
# Mid-Senior Full Stack Developer
#
#
# BCforward
#
#
#
#
#
# Indianapolis, IN
#
#
# DB2 zOS systems programmer
#
#
# Cognizant
#
#
#
#
#
# Indianapolis, IN
#
#
# Job Developer
#
#
# The Community College of Baltimore County
#
#
#
#
#
# Location indicated in Job Description, MD
#
#
# Entry Level Software Developer
#
#
# Genesis10
#
#
#
#
#
# South Bend, IN
#
#
# Application Developer
#
#
# Apex Systems
#
#
#
#
#
# Indianapolis, IN
#
#
# Cloud Architect
#
#
# Randstad Technologies
#
#
#
#
#
# Carmel, IN
#
#
# CMM Programmer
#
#
# Spherion
#
#
#
#
#
# Fort Wayne, IN
#
#
# Urgent Opening ::  Windows Engineer / SCCM Engineer / Windows Systems Engineer  :: Merrillville, IN
#
#
# American Cybersystems
#
#
#
#
#
# Schererville, IN
#
#
# IBM iSeries Programmer
#
#
# Escalade Sports
#
#
#
#
#
# Evansville, IN
#
#
# Sr. Net Developer
#
#
# Beacon Hill Staffing Group, LLC
#
#
#
#
#
# Indianapolis, IN
#
#
# Java Developer
#
#
# Interactive Business Systems
#
#
#
#
#
# Indianapolis, IN
#
#
# C#/.Net Developer
#
#
# Apex Systems
#
#
#
#
#
# Indianapolis, IN
#
#
# Support and Improvement Software Engineer
#
#
# Genesis10
#
#
#
#
#
# Evansville, IN
#
#
# Windows/Linux Engineer - FRKLN
#
#
# Randstad Technologies
#
#
#
#
#
# Indianapolis, IN
#
#
# CMM Calibration Field Service Technician
#
#
# CMM Technology
#
#
#
#
#
# Granger, IN

# %%
import sys
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO

# %%
import pandas as pd

# %%
df1= StringIO(job_title.text)
df = pd.DataFrame(df1)

# %%
df
# Out:
#                                               0
# 0  CMM Calibration Field Service Technician\r\n

# %%
df2 = StringIO(company_name.text)
df =pd.DataFrame(df2)

# %%
df
# Out:
#                   0
# 0                \n
# 1  CMM Technology\n
# 2                \n
# 3                \n

# %%
df3 =StringIO(location.text)
df = pd.DataFrame(df3)

# %%
df
# Out:
#                  0
# 0               \n
# 1             \r\n
# 2  Granger, IN\r\n
# 3               \n
